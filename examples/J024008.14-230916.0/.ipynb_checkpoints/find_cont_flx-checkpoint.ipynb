# %%
import pandas as pd

# %%
print(5+5)

# %%
# Load the uploaded CSV files
file_paths = [
    "/LSB46/J024008.14-230916.0_spw_?_specextract_summary.csv"
]

# Search for the number 6.3201369 in each file
search_value = 6.3201369
results = {}

for path in file_paths:
    df = pd.read_csv(path)
    match = df.isin([search_value]).any().any()
    results[path] = match

results
